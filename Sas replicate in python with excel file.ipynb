# %%
import pandas as pd

# %%
df = pd.read_excel("assignment2.1.xlsx", sheet_name='ta')
# Out:
#                                 Company Name     2000     2001     2002  \
# 0                            20 Microns Ltd.    685.7    779.4    829.9
# 1                           3I Infotech Ltd.    489.4   3563.9   3142.2
# 2                              3M India Ltd.   1069.9   1517.0   1610.4
# 3                      3P Land Holdings Ltd.    570.6    497.4    524.9
# 4                   3Rd Rock Multimedia Ltd.      NaN      NaN      NaN
# 5                52 Weeks Entertainment Ltd.    143.0    131.0    126.1
# 6                        5Paisa Capital Ltd.      NaN      NaN      NaN
# 7                 63 Moons Technologies Ltd.     25.4    514.5    413.3
# 8                            7Nr Retail Ltd.      NaN      NaN      NaN
# 9                   7Seas Entertainment Ltd.     24.1     21.1      NaN
# 10           8K Miles Software Services Ltd.     93.2    104.1    118.5
# 11                         A & M Febcon Ltd.      NaN      NaN      NaN
# ...

# %%
df.dropna(inplace=True)
df1 = df.melt(id_vars="Company Name")
df1=df1.sort_values(by=['Company Name','variable'])
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#               Company Name variable    value
# 0          20 Microns Ltd.     2000    685.7
# 1          20 Microns Ltd.     2001    779.4
# 2          20 Microns Ltd.     2002    829.9
# 3          20 Microns Ltd.     2003    850.5
# 4          20 Microns Ltd.     2004    768.5
# 5          20 Microns Ltd.     2005    698.5
# 6          20 Microns Ltd.     2006    742.9
# 7          20 Microns Ltd.     2007    845.1
# 8          20 Microns Ltd.     2008    978.4
# 9          20 Microns Ltd.     2009   1210.4
# 10         20 Microns Ltd.     2010   1583.7
# 11         20 Microns Ltd.     2011   1984.2
# 12         20 Microns Ltd.     2012   2548.0
# 13         20 Microns Ltd.     2013   2805.9
# 14         20 Microns Ltd.     2014   3207.7
# 15         20 Microns Ltd.     2015   3289.8
# 16         20 Microns Ltd.     2016   3342.3
# 17         20 Microns Ltd.     2017   3661.4
# 18        3I Infotech Ltd.     2000    489.4
# 19        3I Infotech Ltd.     2001   3563.9
# ...
